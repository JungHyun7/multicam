# %% [markdown]
# ## Optuna
#     - 최적의 파라미터를 찾기 위한 라이브러리
#     - 별도의 라이브러리 설치
#     - GridSearchCV와의 가장 큰 차이는 속도 Optuna 우세
#     - GridSearch는 파라미터의 모든 조합을 fitting 확인
#     - Optina는 확률 기반 -> 모든 조합을 다 실행하지는 않는다.
#     - 조합 수 제어 -> GridSearch는 params로 제어, Optuna n_trials 매개변수로 제어

# %%
# !pip install optuna

# %%
import optuna
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.metrics import make_scorer, f1_score

# %%
# iris 데이터 로드
X, Y = load_iris(return_X_y=True)

# %%
# objective 함수를 생성
# 매개변수는 필수
def objective(trial):
    # SVC 모델의 파라미터 경우의 수를 지정
    C = trial.suggest_float("C", 1e-3, 10.0, log=True)
    gamma = trial.suggest_float('gamma', 1e-4, 1.0, log=True)
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf'])
    model = SVC(C = C, gamma=gamma, kernel=kernel)
    
    pipe = Pipeline(
        [
            ('scaler', StandardScaler()),
            ('clf', model)
        ]
    )
    
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(pipe, X, Y, cv=cv, scoring=make_scorer(f1_score, average='macro'))
    
    return scores.mean()

# %%
# optuna를 이용해서 파라미터 찾기
study = optuna.create_study(direction='maximize', study_name='class_tuning')

study.optimize(objective, n_trials=30, show_progress_bar=True)
# Out:
# [I 2025-10-31 17:37:36,035] A new study created in memory with name: class_tuning
# Best trial: 5. Best value: 0.959933:  20%|██        | 6/30 [00:00<00:00, 24.13it/s]
# [I 2025-10-31 17:37:36,074] Trial 0 finished with value: 0.953216374269006 and parameters: {'C': 5.982751993281975, 'gamma': 0.45776334665591856, 'kernel': 'rbf'}. Best is trial 0 with value: 0.953216374269006.
# [I 2025-10-31 17:37:36,127] Trial 1 finished with value: 0.9471101997417787 and parameters: {'C': 0.3210166946102027, 'gamma': 0.7297727763756261, 'kernel': 'rbf'}. Best is trial 0 with value: 0.953216374269006.
# [I 2025-10-31 17:37:36,159] Trial 2 finished with value: 0.8651321398124466 and parameters: {'C': 0.034108135341514675, 'gamma': 0.004740774530307317, 'kernel': 'rbf'}. Best is trial 0 with value: 0.953216374269006.
# [I 2025-10-31 17:37:36,184] Trial 3 finished with value: 0.8584153478324967 and parameters: {'C': 0.011442523481862471, 'gamma': 0.008858067172067233, 'kernel': 'rbf'}. Best is trial 0 with value: 0.953216374269006.
# [I 2025-10-31 17:37:36,206] Trial 4 finished with value: 0.953216374269006 and parameters: {'C': 1.8118443649594669, 'gamma': 0.1147733421807701, 'kernel': 'rbf'}. Best is trial 0 with value: 0.953216374269006.
# [I 2025-10-31 17:37:36,229] Trial 5 finished with value: 0.9599331662489557 and parameters: {'C': 0.13053684982055208, 'gamma': 0.006507153827357215, 'kernel': 'linear'}. Best is trial 5 with value: 0.9599331662489557.
# [I 2025-10-31 17:37:36,256] Trial 6 finished with value: 0.9187055447655798 and parameters: {'C': 0.03025789757875464, 'gamma': 0.002110886589639473, 'kernel': 'linear'}. Best is trial 5 with value: 0.9599331662489557.
# Best trial: 13. Best value: 0.972856:  47%|████▋     | 14/30 [00:00<00:00, 35.90it/s]
# [I 2025-10-31 17:37:36,280] Trial 7 finished with value: 0.8651321398124466 and parameters: {'C': 0.00830953358986067, 'gamma': 0.004308608899397693, 'kernel': 'rbf'}. Best is trial 5 with value: 0.9599331662489557.
# [I 2025-10-31 17:37:36,308] Trial 8 finished with value: 0.918772378516624 and parameters: {'C': 0.03379442261180174, 'gamma': 0.7072739999239942, 'kernel': 'linear'}. Best is trial 5 with value: 0.9599331662489557.
# [I 2025-10-31 17:37:36,333] Trial 9 finished with value: 0.8651321398124466 and parameters: {'C': 0.0022791441411164513, 'gamma': 0.0003621625986754958, 'kernel': 'rbf'}. Best is trial 5 with value: 0.9599331662489557.
# [I 2025-10-31 17:37:36,360] Trial 10 finished with value: 0.9599331662489556 and parameters: {'C': 0.3455124979508571, 'gamma': 0.042033282460604796, 'kernel': 'linear'}. Best is trial 5 with value: 0.9599331662489557.
# [I 2025-10-31 17:37:36,383] Trial 11 finished with value: 0.9599331662489556 and parameters: {'C': 0.3355120876157668, 'gamma': 0.04700897598313938, 'kernel': 'linear'}. Best is trial 5 with value: 0.9599331662489557.
# [I 2025-10-31 17:37:36,409] Trial 12 finished with value: 0.95314852788537 and parameters: {'C': 0.24382840516049997, 'gamma': 0.032897303360422764, 'kernel': 'linear'}. Best is trial 5 with value: 0.9599331662489557.
# [I 2025-10-31 17:37:36,433] Trial 13 finished with value: 0.9728562668393061 and parameters: {'C': 1.3261552838511041, 'gamma': 0.0005954429648749415, 'kernel': 'linear'}. Best is trial 13 with value: 0.9728562668393061.
# [I 2025-10-31 17:37:36,458] Trial 14 finished with value: 0.9661728917348785 and parameters: {'C': 1.9971218398770347, 'gamma': 0.00012261550993109005, 'kernel': 'linear'}. Best is trial 13 with value: 0.9728562668393061.
# Best trial: 16. Best value: 0.979849:  77%|███████▋  | 23/30 [00:00<00:00, 38.86it/s]
# [I 2025-10-31 17:37:36,482] Trial 15 finished with value: 0.9661728917348785 and parameters: {'C': 1.7059861969973888, 'gamma': 0.00012919493090961533, 'kernel': 'linear'}. Best is trial 13 with value: 0.9728562668393061.
# [I 2025-10-31 17:37:36,510] Trial 16 finished with value: 0.9798486114275586 and parameters: {'C': 8.514404706099146, 'gamma': 0.0007781865355717425, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,535] Trial 17 finished with value: 0.9732664995822891 and parameters: {'C': 9.77439837582294, 'gamma': 0.0012855424794145408, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,560] Trial 18 finished with value: 0.9732664995822891 and parameters: {'C': 9.634215779999513, 'gamma': 0.0009530433457943365, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,584] Trial 19 finished with value: 0.9661728917348785 and parameters: {'C': 4.879767263238541, 'gamma': 0.001488730924719783, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,608] Trial 20 finished with value: 0.9661728917348785 and parameters: {'C': 3.7419049278047143, 'gamma': 0.00032374898791962, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,631] Trial 21 finished with value: 0.9798486114275586 and parameters: {'C': 8.685593910963956, 'gamma': 0.0010807308392677963, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,656] Trial 22 finished with value: 0.9732664995822891 and parameters: {'C': 9.328164244625258, 'gamma': 0.002805519516298926, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,681] Trial 23 finished with value: 0.9732664995822891 and parameters: {'C': 0.8147235974808165, 'gamma': 0.0008626909305281566, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# Best trial: 16. Best value: 0.979849: 100%|██████████| 30/30 [00:00<00:00, 37.74it/s]
# [I 2025-10-31 17:37:36,705] Trial 24 finished with value: 0.9661728917348785 and parameters: {'C': 3.8188201058285607, 'gamma': 0.0002490826859123338, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,731] Trial 25 finished with value: 0.9665831244778612 and parameters: {'C': 0.574206877595183, 'gamma': 0.019877993318342984, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,756] Trial 26 finished with value: 0.9661728917348785 and parameters: {'C': 3.212267468323488, 'gamma': 0.0015998215021521566, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,780] Trial 27 finished with value: 0.9732664995822891 and parameters: {'C': 9.06051863017057, 'gamma': 0.0005284788775609732, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,806] Trial 28 finished with value: 0.9732664995822891 and parameters: {'C': 0.7746270860730022, 'gamma': 0.016125855653163334, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.
# [I 2025-10-31 17:37:36,829] Trial 29 finished with value: 0.9661728917348785 and parameters: {'C': 5.927196504262031, 'gamma': 0.21151714871116759, 'kernel': 'linear'}. Best is trial 16 with value: 0.9798486114275586.

# %%
# 최적의 파라미터 출력
print(study.best_params)
# Out:
# {'C': 8.514404706099146, 'gamma': 0.0007781865355717425, 'kernel': 'linear'}

# %%
# 최적의 스코어 확인
print(study.best_value)
# Out:
# 0.9798486114275586

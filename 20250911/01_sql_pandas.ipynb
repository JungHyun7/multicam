# %%
# 라이브러리 로드
import pandas as pd
from database import MyDB

# %%
# 로컬 DB server와의 연결
db1 = MyDB()

# %%
query_select = """
    select * from `emp`
"""
db1.sql_query(query_select)
# Out:
# [{'EMPNO': 7369.0,
#   'ENAME': 'SMITH',
#   'JOB': 'CLERK',
#   'MGR': 7902.0,
#   'HIREDATE': '1980-12-17',
#   'SAL': 800.0,
#   'COMM': 0.0,
#   'DEPTNO': 20.0},
#  {'EMPNO': 7499.0,
#   'ENAME': 'ALLEN',
#   'JOB': 'SALESMAN',
#   'MGR': 7698.0,
#   'HIREDATE': '1981-02-20',
#   'SAL': 1600.0,
#   'COMM': 300.0,
#   'DEPTNO': 30.0},
#  {'EMPNO': 7521.0,
#   'ENAME': 'WARD',
#   'JOB': 'SALESMAN',
#   'MGR': 7698.0,
#   'HIREDATE': '1981-02-22',
#   'SAL': 1250.0,
#   'COMM': 500.0,
#   'DEPTNO': 30.0},
#  {'EMPNO': 7566.0,
#   'ENAME': 'JONES',
#   'JOB': 'MANAGER',
#   'MGR': 7839.0,
#   'HIREDATE': '1981-04-02',
#   'SAL': 2975.0,
#   'COMM': 0.0,
#   'DEPTNO': 20.0},
#  {'EMPNO': 7654.0,
#   'ENAME': 'MARTIN',
#   'JOB': 'SALESMAN',
#   'MGR': 7698.0,
#   'HIREDATE': '1981-09-28',
#   'SAL': 1250.0,
#   'COMM': 1400.0,
#   'DEPTNO': 30.0},
#  {'EMPNO': 7698.0,
#   'ENAME': 'BLAKE',
#   'JOB': 'MANAGER',
#   'MGR': 7839.0,
#   'HIREDATE': '1981-05-01',
#   'SAL': 2850.0,
# ...

# %%
query_1 = """
    select * from `emp`
"""
emp_df = pd.DataFrame(db1.sql_query(query_1))
emp_df
# Out:
#      EMPNO   ENAME        JOB     MGR    HIREDATE     SAL    COMM  DEPTNO
# 0   7369.0   SMITH      CLERK  7902.0  1980-12-17   800.0     0.0    20.0
# 1   7499.0   ALLEN   SALESMAN  7698.0  1981-02-20  1600.0   300.0    30.0
# 2   7521.0    WARD   SALESMAN  7698.0  1981-02-22  1250.0   500.0    30.0
# 3   7566.0   JONES    MANAGER  7839.0  1981-04-02  2975.0     0.0    20.0
# 4   7654.0  MARTIN   SALESMAN  7698.0  1981-09-28  1250.0  1400.0    30.0
# 5   7698.0   BLAKE    MANAGER  7839.0  1981-05-01  2850.0     0.0    30.0
# 6   7782.0   CLARK    MANAGER  7839.0  1981-06-09  2450.0     0.0    10.0
# 7   7788.0   SCOTT    ANALYST  7566.0  1987-06-28  3000.0     0.0    20.0
# 8   7839.0    KING  PRESIDENT     0.0  1981-11-17  5000.0     0.0    10.0
# 9   7844.0  TURNER   SALESMAN  7698.0  1981-09-08  1500.0     0.0    30.0
# 10  7876.0   ADAMS      CLERK  7788.0  1987-07-13  1100.0     0.0    20.0
# 11  7900.0   JAMES      CLERK  7698.0  1981-12-03   950.0     0.0    30.0
# ...

# %%
query_2 = """
    select * from `dept`
"""
dept_df = pd.DataFrame(db1.sql_query(query_2))
dept_df
# Out:
#    DEPTNO       DNAME       LOC
# 0    10.0  ACCOUNTING  NEW YORK
# 1    20.0    RESEARCH    DALLAS
# 2    30.0       SALES   CHICAGO
# 3    40.0  OPERATIONS    BOSTON

# %%
# emp table에서 SAL 컬럼의 데이터가 1500이상인 사원의 정보를 확인해본다
# DataFrame을 이용하여 확인
# 인덱스의 조건식 -> 기준이 인덱스의 값, value는 bool 형태의 데이터가 들어온다.(Series)
flag = emp_df['SAL'] >= 1500
# 인덱스의 조건식을 이용하여 데이터프레임을 필터링
    # loc[인덱스의 조건, 컬럼의 조건]
emp_df.loc[flag, ]
# Out:
#      EMPNO   ENAME        JOB     MGR    HIREDATE     SAL   COMM  DEPTNO
# 1   7499.0   ALLEN   SALESMAN  7698.0  1981-02-20  1600.0  300.0    30.0
# 3   7566.0   JONES    MANAGER  7839.0  1981-04-02  2975.0    0.0    20.0
# 5   7698.0   BLAKE    MANAGER  7839.0  1981-05-01  2850.0    0.0    30.0
# 6   7782.0   CLARK    MANAGER  7839.0  1981-06-09  2450.0    0.0    10.0
# 7   7788.0   SCOTT    ANALYST  7566.0  1987-06-28  3000.0    0.0    20.0
# 8   7839.0    KING  PRESIDENT     0.0  1981-11-17  5000.0    0.0    10.0
# 9   7844.0  TURNER   SALESMAN  7698.0  1981-09-08  1500.0    0.0    30.0
# 12  7902.0    FORD    ANALYST  7566.0  1981-12-03  3000.0    0.0    20.0

# %%
# select query문을 이용하여 SAL이 1500이상인 데이터를 확인
query_3 = """
    select * from `emp`
    where `SAL` >= 1500
"""
pd.DataFrame(db1.sql_query(query_3))
# Out:
#     EMPNO   ENAME        JOB     MGR    HIREDATE     SAL   COMM  DEPTNO
# 0  7499.0   ALLEN   SALESMAN  7698.0  1981-02-20  1600.0  300.0    30.0
# 1  7566.0   JONES    MANAGER  7839.0  1981-04-02  2975.0    0.0    20.0
# 2  7698.0   BLAKE    MANAGER  7839.0  1981-05-01  2850.0    0.0    30.0
# 3  7782.0   CLARK    MANAGER  7839.0  1981-06-09  2450.0    0.0    10.0
# 4  7788.0   SCOTT    ANALYST  7566.0  1987-06-28  3000.0    0.0    20.0
# 5  7839.0    KING  PRESIDENT     0.0  1981-11-17  5000.0    0.0    10.0
# 6  7844.0  TURNER   SALESMAN  7698.0  1981-09-08  1500.0    0.0    30.0
# 7  7902.0    FORD    ANALYST  7566.0  1981-12-03  3000.0    0.0    20.0

# %%
# emp table에서 SAL이 1500 이상 이고 JOB이 MANAGER인 사원의 정보를 확인
query_4 = """
    select * from `emp`
    where `SAL` >= 1500 and `JOB` = "MANAGER"
"""

pd.DataFrame(db1.sql_query(query_4))
# Out:
#     EMPNO  ENAME      JOB     MGR    HIREDATE     SAL  COMM  DEPTNO
# 0  7566.0  JONES  MANAGER  7839.0  1981-04-02  2975.0   0.0    20.0
# 1  7698.0  BLAKE  MANAGER  7839.0  1981-05-01  2850.0   0.0    30.0
# 2  7782.0  CLARK  MANAGER  7839.0  1981-06-09  2450.0   0.0    10.0

# %%
# 위의 조건식을 이용하여 같은 결과를 DataFrame에서 출력하시오
flag2 = emp_df['JOB'] == 'MANAGER'

emp_df.loc[flag & flag2, ]
# Out:
#     EMPNO  ENAME      JOB     MGR    HIREDATE     SAL  COMM  DEPTNO
# 3  7566.0  JONES  MANAGER  7839.0  1981-04-02  2975.0   0.0    20.0
# 5  7698.0  BLAKE  MANAGER  7839.0  1981-05-01  2850.0   0.0    30.0
# 6  7782.0  CLARK  MANAGER  7839.0  1981-06-09  2450.0   0.0    10.0

# %%
emp_df.query(
    '(SAL >= 1500) and (JOB == "MANAGER")'
    )
# Out:
#     EMPNO  ENAME      JOB     MGR    HIREDATE     SAL  COMM  DEPTNO
# 3  7566.0  JONES  MANAGER  7839.0  1981-04-02  2975.0   0.0    20.0
# 5  7698.0  BLAKE  MANAGER  7839.0  1981-05-01  2850.0   0.0    30.0
# 6  7782.0  CLARK  MANAGER  7839.0  1981-06-09  2450.0   0.0    10.0

# %%
# SAL의 데이터가 1500이상이고 2500 이하인 사원번호와 사원 이름을 출력해본다.
query_5 = """
    select `EMPNO` as "사원번호", `ENAME` as "사원이름"
    from `emp`
    where `SAL` >= 1500 
    and
    `SAL` <= 2500
"""

pd.DataFrame(db1.sql_query(query_5))
# Out:
#      사원번호    사원이름
# 0  7499.0   ALLEN
# 1  7782.0   CLARK
# 2  7844.0  TURNER

# %%
query_6 = """
    select `EMPNO` as "사원번호", `ENAME` as "사원이름"
    from `emp`
    where `SAL` between 1500 and 2500
"""

pd.DataFrame(db1.sql_query(query_6))
# Out:
#      사원번호    사원이름
# 0  7499.0   ALLEN
# 1  7782.0   CLARK
# 2  7844.0  TURNER

# %%
# emp_df를 이용하여 위와 같은 결과를 출력하시오
flag4 = emp_df['SAL'] <= 2500

emp_df.loc[flag & flag4, ['EMPNO', 'ENAME']]
# Out:
#     EMPNO   ENAME
# 1  7499.0   ALLEN
# 6  7782.0   CLARK
# 9  7844.0  TURNER

# %%
emp_df.loc[
    emp_df['SAL'].isin(range(1500, 2501)),
    ['EMPNO', 'ENAME']
]
# Out:
#     EMPNO   ENAME
# 1  7499.0   ALLEN
# 6  7782.0   CLARK
# 9  7844.0  TURNER

# %%
emp_df.loc[
    emp_df['SAL'].between(1500, 2000),
    ['EMPNO', 'ENAME']
]
# Out:
#     EMPNO   ENAME
# 1  7499.0   ALLEN
# 9  7844.0  TURNER

# %%
emp_df.query(
    '(SAL >= 1500) and (SAL <= 2500)'
    )[['EMPNO', 'ENAME']]
# Out:
#     EMPNO   ENAME
# 1  7499.0   ALLEN
# 6  7782.0   CLARK
# 9  7844.0  TURNER

# %%
# sql query 조건에서 2개의 데이터중 하나가 포함되어있는 조건
# JOB의 데이터가 MANAGER이거나 SALESMAN인 사원의 정보를 출력
query_7 = """
    select * from `EMP`
    where `JOB` = "MANAGER"
    or
    `JOB` = "SALESMAN"
"""
pd.DataFrame(db1.sql_query(query_7))
# Out:
#     EMPNO   ENAME       JOB     MGR    HIREDATE     SAL    COMM  DEPTNO
# 0  7499.0   ALLEN  SALESMAN  7698.0  1981-02-20  1600.0   300.0    30.0
# 1  7521.0    WARD  SALESMAN  7698.0  1981-02-22  1250.0   500.0    30.0
# 2  7566.0   JONES   MANAGER  7839.0  1981-04-02  2975.0     0.0    20.0
# 3  7654.0  MARTIN  SALESMAN  7698.0  1981-09-28  1250.0  1400.0    30.0
# 4  7698.0   BLAKE   MANAGER  7839.0  1981-05-01  2850.0     0.0    30.0
# 5  7782.0   CLARK   MANAGER  7839.0  1981-06-09  2450.0     0.0    10.0
# 6  7844.0  TURNER  SALESMAN  7698.0  1981-09-08  1500.0     0.0    30.0

# %%
query_8 = """
    select * from `EMP`
    where
    `JOB` in ("MANAGER", "SALESMAN")
"""
pd.DataFrame(db1.sql_query(query_8))
# Out:
#     EMPNO   ENAME       JOB     MGR    HIREDATE     SAL    COMM  DEPTNO
# 0  7499.0   ALLEN  SALESMAN  7698.0  1981-02-20  1600.0   300.0    30.0
# 1  7521.0    WARD  SALESMAN  7698.0  1981-02-22  1250.0   500.0    30.0
# 2  7566.0   JONES   MANAGER  7839.0  1981-04-02  2975.0     0.0    20.0
# 3  7654.0  MARTIN  SALESMAN  7698.0  1981-09-28  1250.0  1400.0    30.0
# 4  7698.0   BLAKE   MANAGER  7839.0  1981-05-01  2850.0     0.0    30.0
# 5  7782.0   CLARK   MANAGER  7839.0  1981-06-09  2450.0     0.0    10.0
# 6  7844.0  TURNER  SALESMAN  7698.0  1981-09-08  1500.0     0.0    30.0

# %%
# 사원의 이름이 특정 문자로 시작하는 사원의 정보를 확인
query_9 = """
    select * from `emp`
    where `ENAME` LIKE "S%%"
"""
pd.DataFrame(db1.sql_query(query_9))
# Out:
#     EMPNO  ENAME      JOB     MGR    HIREDATE     SAL  COMM  DEPTNO
# 0  7369.0  SMITH    CLERK  7902.0  1980-12-17   800.0   0.0    20.0
# 1  7788.0  SCOTT  ANALYST  7566.0  1987-06-28  3000.0   0.0    20.0

# %%
# emp_df에서 ENAME이 S로 시작하는 사원의 정보를 출력하자 출력하자
# case1 : 반복문
word = 'S'
flag_list = []
for i in emp_df['ENAME']:
    print( word.lower() == i[ : len(word)].lower())
    flag_list.append(
        word.lower() == i[ : len(word)].lower()
    )
    #S로 끝나는 사람
    # flag_list.append(
    #     word.lower() == i[ -len(word) : ].lower()
    # )

emp_df.loc[flag_list, ]
# Out:
#      EMPNO  ENAME      JOB     MGR    HIREDATE     SAL  COMM  DEPTNO
# 3   7566.0  JONES  MANAGER  7839.0  1981-04-02  2975.0   0.0    20.0
# 10  7876.0  ADAMS    CLERK  7788.0  1987-07-13  1100.0   0.0    20.0
# 11  7900.0  JAMES    CLERK  7698.0  1981-12-03   950.0   0.0    30.0

# %%
# 특정 문자가 포함되어있는가?

# %%
flag_list = []

word = 's'

for i in emp_df['ENAME']:
    flag_list.append(
        word.lower() in i.lower()
    )
    
emp_df.loc[flag_list, ]
# Out:
#      EMPNO  ENAME      JOB     MGR    HIREDATE     SAL  COMM  DEPTNO
# 0   7369.0  SMITH    CLERK  7902.0  1980-12-17   800.0   0.0    20.0
# 3   7566.0  JONES  MANAGER  7839.0  1981-04-02  2975.0   0.0    20.0
# 7   7788.0  SCOTT  ANALYST  7566.0  1987-06-28  3000.0   0.0    20.0
# 10  7876.0  ADAMS    CLERK  7788.0  1987-07-13  1100.0   0.0    20.0
# 11  7900.0  JAMES    CLERK  7698.0  1981-12-03   950.0   0.0    30.0

# %%
word = 's'
emp_df['ENAME'].map(
    lambda x : x.lower().startswith(word)
)
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# Name: ENAME, dtype: bool

# %%
word = 's'
emp_df['ENAME'].map(
    lambda x : x.lower().endswith(word)
)
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12    False
# 13    False
# Name: ENAME, dtype: bool

# %%
# contains -> 특정문자 포함여부 (str)
emp_df['ENAME'].str.lower().str.contains(word.lower())

# %%
emp_df[emp_df['ENAME'].str.startswith('S')]
# Out:
#     EMPNO  ENAME      JOB     MGR    HIREDATE     SAL  COMM  DEPTNO
# 0  7369.0  SMITH    CLERK  7902.0  1980-12-17   800.0   0.0    20.0
# 7  7788.0  SCOTT  ANALYST  7566.0  1987-06-28  3000.0   0.0    20.0

# %% [markdown]
# ### 데이터프레임의 결합
# - 유니온 결합
#     - 단순하게 행을 결합하거나 열을 결합하는 방식
#     - pandas에 내장된 concat() 함수를 이용
#         - concat([데이터프레임1, 데이터프레임2,...])
#             - axis 매개변수
#                 - 0(index, rows) : 단순 행을 결합
#                 - 1(columns) : 단순 열을 결합
#             - ignore_index 매개변수
#                 - False : 결합되는 기준(인덱스, 컬럼)을 보존
#                 - True : 결합되는 기준(인덱스, 컬럼)을 초기화
# - 조인 결합
#     - 특정한 조건에 맞춰서 열을 결합
#     - 데이터프레임과 데이터프레임 간의 결합 -> 특정 컬럼의 데이터들이 같은 값들로 이루어져 있는 경우에 열을 추가하는 결합 방식
#     - pandas, DataFrame에 내장된 merge() 함수 이용
#     - 조건에 맞춰서 열을 결합하는 방식이기 때문에 concat()과는 다르게 2개의 데이터프레임만 결합
#         - pd.merge(데이터프레임명, 데이터프레임명) // df.merge(데이터프레임명)
#             - on 매개변수
#                 - 조건식(두 개의 데이터프레임이 공통적으로 가지고 있는 데이터 컬럼명)
#                 - 두 개의 데이터프레임이 공통적으로 가지고 있는 데이터가 컬럼의 이름이 다른 경우
#                     - left_on 매개변수 첫번째 데이터프레임의 컬럼명
#                     - right_on 매개변수 두번째 데이터프레임의 컬럼명
#             - how 매개변수
#                 - 조인 결합의 방식을 지정
#                     - inner : 두 개의 데이터프레임이 공통적으로 가지고 있는 데이터만 결합하여 출력
#                     - left : 왼쪽(첫번째) 데이터프레임을 기준으로 결합
#                     - right : 오른쪽(두번째) 데이터프레임을 기준으로 결합
#                     - outer : 두개의 데이터프레임의 합집합

# %%
# sql을 이용하여 tran_1, tran_2 테이블을 유니언 결합
query_10 = """
    select * from `tran_1`
    union
    select * from `tran_2`
"""
pd.DataFrame(db1.sql_query(query_10))
# Out:
#      transaction_id   price         payment_date customer_id
# 0       T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1       T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2       T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3       T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4       T0000000117  170000  2019-02-01 04:33:46    PL542865
# ...             ...     ...                  ...         ...
# 6781    T0000006894  180000  2019-07-31 21:20:44    HI400734
# 6782    T0000006895   85000  2019-07-31 21:52:48    AS339451
# 6783    T0000006896  100000  2019-07-31 23:35:25    OA027325
# 6784    T0000006897   85000  2019-07-31 23:39:35    TS624738
# 6785    T0000006898   85000  2019-07-31 23:41:38    AS834214
#
# [6786 rows x 4 columns]

# %%
# 상대 경로 : 상위로 이동(../) -> csv 폴더 이동(csv/) -> tran_1.csv 이동
tran_1 = pd.read_csv("./../csv/tran_1.csv")
tran_2 = pd.read_csv("./../csv/tran_2.csv")
tran_d_1 = pd.read_csv("./../csv/tran_d_1.csv")
tran_d_2 = pd.read_csv("./../csv/tran_d_2.csv")

# %%
pd.concat([tran_1, tran_2], axis=0)
# Out:
#      transaction_id   price         payment_date customer_id
# 0       T0000000113  210000  2019-02-01 01:36:57    PL563502
# 1       T0000000114   50000  2019-02-01 01:37:23    HD678019
# 2       T0000000115  120000  2019-02-01 02:34:19    HD298120
# 3       T0000000116  210000  2019-02-01 02:47:23    IK452215
# 4       T0000000117  170000  2019-02-01 04:33:46    PL542865
# ...             ...     ...                  ...         ...
# 1781    T0000006894  180000  2019-07-31 21:20:44    HI400734
# 1782    T0000006895   85000  2019-07-31 21:52:48    AS339451
# 1783    T0000006896  100000  2019-07-31 23:35:25    OA027325
# 1784    T0000006897   85000  2019-07-31 23:39:35    TS624738
# 1785    T0000006898   85000  2019-07-31 23:41:38    AS834214
#
# [6786 rows x 4 columns]

# %%
# 조인 결합
# tran_1, tran_d_1 조인 결합
# 조건 확인 -> 두 개의 데이터프레임이 가지고 있는 같은 데이터가 무엇인가?

# %%
tran_1.head(1)
# Out:
#   transaction_id   price         payment_date customer_id
# 0    T0000000113  210000  2019-02-01 01:36:57    PL563502

# %%
tran_d_1.head(1)
# Out:
#    detail_id transaction_id item_id  quantity
# 0          0    T0000000113    S005         1

# %%
# 두 개의 데이터프레임에서 공통적으로 가지고 있는 데이터는 transaction_id
query_11 = """
    select 
    t1.transaction_id '거래 식별자',
    payment_date '지불 일자',
    price '가격',
    quantity '개수',
    item_id '아이템 이름'
    from
    `tran_1` as `t1` left join `tran_d_1` as `td1`
    on `t1`.`transaction_id` = `td1`.`transaction_id`
"""
pd.DataFrame(db1.sql_query(query_11))
# Out:
#            거래 식별자                지불 일자      가격   개수 아이템 이름
# 0     T0000000113  2019-02-01 01:36:57  210000  1.0   S005
# 1     T0000000114  2019-02-01 01:37:23   50000  1.0   S001
# 2     T0000000115  2019-02-01 02:34:19  120000  1.0   S003
# 3     T0000000116  2019-02-01 02:47:23  210000  1.0   S005
# 4     T0000000117  2019-02-01 04:33:46  170000  2.0   S002
# ...           ...                  ...     ...  ...    ...
# 5238  T0000005108  2019-06-15 02:42:41  210000  NaN   None
# 5239  T0000005109  2019-06-15 03:36:16  150000  NaN   None
# 5240  T0000005110  2019-06-15 03:44:06   50000  NaN   None
# 5241  T0000005111  2019-06-15 04:14:06  210000  NaN   None
# 5242  T0000005112  2019-06-15 04:42:38   50000  NaN   None
#
# [5243 rows x 5 columns]

# %%
# 위의 결과와 같은 작업
# left join 결합
tran_df = pd.merge(tran_1, tran_d_1,
        how= 'left',
        on='transaction_id')

# %%
tran_df = pd.merge()

# %%
# 특정 컬럼만 필터링(transction_id, payment_id, price, quantity, item_id)
tran_df = tran_df[['transaction_id', 'payment_date', 'price', 'quantity', 'item_id']]

# %%
# 컬럼의 이름을 변경
#case1 -> renmae() : 인덱스를 재지정하거나 컬럼을 재지정 
tran_df.rename(
    columns= {
        'transaction_id' : '거래 식별자',
        'payment_date' : '지불 일자',
        'price' : '가격',
        'quantity' : '개수',
        'item_id' : '아이템 이름'
    },
    # replace = True
)

# case2 -> columns
# 데이터프레임 안에 저장된 변수 columns를 변경
# 바로 대입하는 경우 유의할 점 -> 기존의 컬럼의 개수와 대입하려는 컬럼의 개수가 같아야 한다.
tran_df.columns = ['거래 식별자', '지불 일자', '가격' ,'개수' ,'아이템 이름']

# %%
tran_df
# Out:
#            거래 식별자                지불 일자      가격   개수 아이템 이름
# 0     T0000000113  2019-02-01 01:36:57  210000  1.0   S005
# 1     T0000000114  2019-02-01 01:37:23   50000  1.0   S001
# 2     T0000000115  2019-02-01 02:34:19  120000  1.0   S003
# 3     T0000000116  2019-02-01 02:47:23  210000  1.0   S005
# 4     T0000000117  2019-02-01 04:33:46  170000  2.0   S002
# ...           ...                  ...     ...  ...    ...
# 5238  T0000005108  2019-06-15 02:42:41  210000  NaN    NaN
# 5239  T0000005109  2019-06-15 03:36:16  150000  NaN    NaN
# 5240  T0000005110  2019-06-15 03:44:06   50000  NaN    NaN
# 5241  T0000005111  2019-06-15 04:14:06  210000  NaN    NaN
# 5242  T0000005112  2019-06-15 04:42:38   50000  NaN    NaN
#
# [5243 rows x 5 columns]

# %%
# 정렬 방식
# DataFrame -> sort_value()
# SQL -> order by [ASC : 오름차순, DESC : 내림차순]


query_12 = """
    select * 
    from `emp`
    where `JOB` = 'MANAGER'
    order by `ename` DESC
"""
pd.DataFrame(db1.sql_query(query_12))
# Out:
#     EMPNO  ENAME      JOB     MGR    HIREDATE     SAL  COMM  DEPTNO
# 0  7566.0  JONES  MANAGER  7839.0  1981-04-02  2975.0   0.0    20.0
# 1  7782.0  CLARK  MANAGER  7839.0  1981-06-09  2450.0   0.0    10.0
# 2  7698.0  BLAKE  MANAGER  7839.0  1981-05-01  2850.0   0.0    30.0

# %%
# 그룹화  sql
# job을 기준으로 그룹화 -> SAL의 평균을 구한다. -> job이라는 컬럼과 sal의 평균 컬럼으로 지정 -> SAL을 기준으로 내림차순한다.

query_13 = """
    select `JOB`, avg(`SAL`) 평균임금
    from `emp`
    group by `JOB`
    order by 평균임금  desc
"""
pd.DataFrame(db1.sql_query(query_13))
# Out:
#          JOB         평균임금
# 0  PRESIDENT  5000.000000
# 1    ANALYST  3000.000000
# 2    MANAGER  2758.333333
# 3   SALESMAN  1400.000000
# 4      CLERK  1037.500000

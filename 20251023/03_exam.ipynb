# %%
import pandas as pd

# %%
df = pd.read_json("../data/민원(콜센터) 질의응답_다산콜센터_일반행정 문의_Training.json")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50336 entries, 0 to 50335
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   도메인        50336 non-null  object
#  1   카테고리       50336 non-null  object
#  2   대화셋일련번호    50336 non-null  object
#  3   화자         50336 non-null  object
#  4   문장번호       50336 non-null  int64
#  5   고객의도       50336 non-null  object
#  6   상담사의도      50336 non-null  object
#  7   QA         50336 non-null  object
#  8   고객질문(요청)   50336 non-null  object
#  9   상담사질문(요청)  50336 non-null  object
#  10  고객답변       50336 non-null  object
#  11  상담사답변      50336 non-null  object
#  12  개체명        50336 non-null  object
#  13  용어사전       50336 non-null  object
#  14  지식베이스      50336 non-null  object
# dtypes: int64(1), object(14)
# memory usage: 5.8+ MB

# %%
# 결측치의 개수를 확인
df.isna().sum()
# Out:
# 도메인          0
# 카테고리         0
# 대화셋일련번호      0
# 화자           0
# 문장번호         0
# 고객의도         0
# 상담사의도        0
# QA           0
# 고객질문(요청)     0
# 상담사질문(요청)    0
# 고객답변         0
# 상담사답변        0
# 개체명          0
# 용어사전         0
# 지식베이스        0
# dtype: int64

# %%
df.head(10)
# Out:
#      도메인     카테고리 대화셋일련번호   화자  문장번호   고객의도  상담사의도 QA             고객질문(요청)  \
# 0  다산콜센터  일반행정 문의   B2240   고객     1  지방세납부         Q  지방세를 내려면 어떻게 해야됩니까?
# 1  다산콜센터  일반행정 문의   B2240  상담사     2         지방세납부  A
# 2  다산콜센터  일반행정 문의   B2240   고객     3  지방세납부         Q        은행 어플에서도 됩니까?
# 3  다산콜센터  일반행정 문의   B2240  상담사     4         지방세납부  Q
# 4  다산콜센터  일반행정 문의   B2240   고객     5  지방세납부         A
# 5  다산콜센터  일반행정 문의   B2240  상담사     6         지방세납부  A
# 6  다산콜센터  일반행정 문의   B2240   고객     7  지방세납부         Q      은행을 직접방문해도 됩니까?
# 7  다산콜센터  일반행정 문의   B2240  상담사     8         지방세납부  A
# 8  다산콜센터  일반행정 문의   B2240   고객     9  지방세납부         Q     은행위치 좀 알 수 있습니까?
# 9  다산콜센터  일반행정 문의   B2240  상담사    10         지방세납부  Q
#
#            상담사질문(요청)              고객답변                                상담사답변  \
# 0
# 1                                            이용하시는 은행의 사이트에서 지방세 납부가 가능합니다.
# 2
# 3  어떤 은행을 이용하고 계십니까?
# 4                     기업은행을 이용하고 있습니다.
# 5                                       그럼 스마트폰에서 기업은행 어플을 설치하시면 납부가 가능합니다.
# 6
# 7                                                              방문납부도 가능합니다.
# 8
# 9    어느지점으로 안내해드릴까요?
#
#                  개체명                 용어사전    지식베이스
# 0                 지방세              지방세/세금   지방세,세금
# 1    은행, 사이트, 지방세, 납부     은행/공공기관/ 지방세/세금   사이트,세금
# 2              은행, 어플             은행/공공기관  어플,공공기관
# 3                  은행             은행/공공기관  은행,공공기관
# 4                기업은행             기업은행/상호  기업은행,상호
# 5  스마트폰, 기업은행, 어플, 납부  스마트폰/전자기기/ 기업은행/상호  기업은행,상호
# 6                  은행             은행/공공기관  은행,공공기관
# 7
# 8                  은행             은행/공공기관  은행,공공기관
# 9

# %% [markdown]
# ### 문제
# 1. 일반행정 데이터와 대중 교통 데이터를 로드
# 2. 두개의 데이터프레임을 결합(단순한 행 결합)
# 3.
